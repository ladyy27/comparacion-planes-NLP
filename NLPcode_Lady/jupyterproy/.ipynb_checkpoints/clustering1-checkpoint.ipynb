# %%
import codecs
import pandas as pd
import nbimporter
import spacy
from textblob import TextBlob
from MySQL_connection import *
from preprocessing import *
from detect_es import *
from sklearn.feature_extraction.text import TfidfVectorizer
import string
import math
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
from sklearn.externals import joblib
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import ward, dendrogram
from scipy import sparse
import pickle

# %%
set_connectionMySQL()

# %%
#Recuperar archivos de datos
"""
titulos_asignaturas= stopwordsList("files/asignaturas.txt")
carreras_asignaturas= stopwordsList("files/carreras.txt")
resultados_asignaturas= stopwordsList("files/resultados.txt")
asignatura_titulacion= stopwordsList("files/asignatura_tit.txt")
"""
es_stopwords= stopwordsList("stopwords/spanish")
punt_stopwords= stopwordsList("stopwords/puntuacion")

lista_materias = []
titulos_asignaturas = ieee_select_query("SELECT o FROM planes WHERE p = 'asignatura'")
for asig in titulos_asignaturas:
    lista_materias.append(asig['o'])
    
print (lista_materias)

ranks = []
for i in range(0,len(lista_materias)):
    ranks.append(i)
    
#print (lista_materias)
    
#print (len(ranks))
#print (len(titulos_asignaturas))
#print (len(resultados_asignaturas))
# Out:
# ['FÍSICA PARA LAS CIENCIAS BIOMÉDICAS', 'INTEGRADO DE CLÍNICA MEDICA: ONCOLOGÍA', 'INTEGRADO DE CLÍNICA III CARDIOVASCULAR', 'MORFOFUNCIONAL IV NEUROFISIOLOGÍA TEORÍA', 'MORFOFUNCIONAL II ANATOMÍA TEORÍA', 'MORFOFUNCIONAL II FISIOLOGÍA PRÁCTICA', 'MORFOFUNCIONAL I EMBRIOLOGÍA', 'MORFOFUNCIONAL I HISTOLOGÍA TEORÍA', 'MICROFINANZAS', 'ADMINISTRACIÓN I', 'ECONOMÍA DEL ECUADOR', 'MORFOFUNCIONAL III ANATOMÍA TEORÍA', 'MORFOFUNCIONAL III FISIOLOGÍA PRÁCTICA', 'CUIDADOS DE LA PERSONA ENFERMA', 'ADMINISTRACIÓN EN SALUD', 'EXTERNADO GP 3.3', 'BIOQUÍMICA', 'CONTABILIDAD GENERAL', 'MORFOFUNCIONAL II HISTOLOGÍA TEORÍA', 'FUNDAMENTOS FILOSÓFICOS DE LA MEDICINA', 'INTEGRADO DE CLÍNICAS QUIRÚRGICAS TRAUMATOLOGÍA', 'MORFOFUNCIONAL I ANATOMÍA TEORÍA', 'SEMIOTECNIA', 'TALLERES: RCP, SIGNOS VITALES, VENDAJES, INYECCIONES', 'MATEMÁTICAS PARA LAS CIENCIAS BIOMÉDICAS', 'FAMILIA Y VIDA GP1.1', 'INTEGRADO DE CLÍNICA I: FISIOPATOLOGÍA', 'INTEGRADO DE CLÍNICA QUIRÚRGICAS UROLOGÍA', 'BIOLOGÍA GENERAL', 'MORFOFUNCIONAL I HISTOLOGÍA PRÁCTICA', 'MICROBIOLOGÍA Y PARASITOLOGÍA', 'MORFOFUNCIONAL II ANATOMÍA PRÁCTICA', 'FINANZAS', 'PANADERÍA Y PASTELERÍA I', 'PARTICIPACIÓN CIUDADANA, TRANSPARENCIA Y LUCHA CONTRA LA CORRUPCIÓN', 'MORFOFUNCIONAL III ANATOMÍA PRÁCTICA', 'INTEGRADO DE CLÍNICA I: SEMIOLOGÍA PRÁCTICA', 'INTEGRADO DE CLÍNICA I: SEMIOLOGÍA TEÓRICA', 'INTEGRADO DE CLÍNICAS QUIRÚRGICAS MEDICINA CRÍTICA Y URGENCIAS', 'INTERNADO: CIRUGÍA, MEDICINA INTERNA, GINECOLOGÍA-OBSTETRICIA, PEDIATRÍA GP 4.2', 'MEDICINA COMUNITARIA GP 2.1', 'MORFOFUNCIONAL II FISIOLOGÍA TEORÍA', ' ERGONOMÍA ENFOCADA AL DISEÑO, POSTUROLOGÍA, FISIOLOGÍA Y ÁREAS COGNITIVAS', 'FAMILIA Y VIDA GP 1.2', 'GINECOLOGÍA  Y OBSTETRICIA: GINECOLOGÍA', 'INTEGRADO DE CLÍNICA MEDICA: NEUROLOGÍA', 'INTEGRADO DE CLÍNICA III RESPIRATORIO', 'ÉTICA MEDICA', 'BIOESTADÍSTICA', 'INTRODUCCIÓN A LA AUDITORÍA', 'FIBRAS NATURALES', 'COCINA I', 'ENOLOGÍA Y MIXOLOGÍA', 'TURISMO, GASTRONOMIA Y NUEVAS TECNOLOGÍAS', 'SALUD PÚBLICA', 'GINECOLOGÍA Y OBSTETRICIA: OBSTETRICIA', 'INTEGRADO DE CLÍNICA MEDICA: INMUNO-REUMATOLOGÍA', 'INTRODUCCIÓN A LOS ESTUDIOS MÉDICOS', 'MORFOFUNCIONAL I ANATOMÍA PRÁCTICA', 'PERIODISMO EN BASE DE DATOS', 'ARQUITECTURA LATINOAMERICANA: ECUADOR Y PERÚ', 'BIOLOGÍA CELULAR Y MOLECULAR', 'MORFOFUNCIONAL III FISIOLOGÍA TEORÍA', 'PATOLOGÍA GENERAL', 'INTEGRADO DE CLÍNICAS QUIRÚRGICAS CIRUGÍA GENERAL Y TÉCNICA QUIRÚRGICA', 'EXTERNADO GP 3.1', 'INTEGRADO DE CLINICA III IMAGEN', 'INTEGRADO DE CLINICA III RENAL', 'INTRODUCCION A LA INGENIERÍA QUÍMICA, INDUSTRIA, AMBIENTE Y DESARROLLO', 'MORFOFUNCIONAL IV NEUROFISIOLOGÍA PRÁCTICA', 'MORFOFUNCIONAL II HISTOLOGÍA PRÁCTICA', 'CIENCIAS PENALES', 'NUEVAS TECNOLOGÍAS APLICADAS AL DERECHO', 'INTRODUCCIÓN AL DERECHO', 'GESTIÓN PRODUCTIVA GP 2', 'DERECHO PROCESAL LABORAL', 'TRABAJO DE FIN DE CARRERA 4.1', 'DERECHO CIVIL IV, OBLIGACIONES Y CONTRATOS', 'DERECHO INTERNACIONAL PRIVADO', 'DERECHO CONSTITUCIONAL', 'RELACIONES PÚBLICAS Y PROTOCOLO', 'FILOSOFÍA DEL DERECHO', 'MEDIOS ALTERNATIVOS DE RESOLUCIÓN DE CONFLICTOS', 'DERECHO PROCESAL CIVIL II', 'DERECHO PROCESAL PENAL I', 'DERECHO PENAL I', 'GESTIÓN PRODUCTIVA GP 1', 'DERECHO DE INTEGRACIÓN', 'DERECHO INTERNACIONAL PÚBLICO', 'LEYES ESPECIALES I, INQUILINATO, NOTARIAL Y REGISTRAL', 'DERECHO AMBIENTAL', 'GESTIÓN PRODUCTIVA 3.1', 'DERECHO CIVIL II, BIENES', 'TRABAJO DE FIN DE CARRERA 4.2', 'GESTIÓN PRODUCTIVA 3.2', 'PSICOTERAPIA I', 'PSICOLOGÍA GENERAL', 'GESTIÓN PRODUCTIVA 3.1', 'PSICOPATOLOGÍA I', 'EVALUACIÓN Y DIAGNÓSTICO I', 'PSICOLOGÍA SOCIAL', 'TÉCNICAS DE INTERVENCIÓN PSICOPEDAGÓGICA', 'GESTIÓN PRODUCTIVA GP 1', 'PSICOLOGÍA DEL DESEMPEÑO II', 'ESTADÍSTICA II', 'TRABAJO DE FIN DE CARRERA GP 4.2', 'GESTIÓN PRODUCTIVA 4.1', 'PSICOLOGÍA ORGANIZACIONAL', 'PSICOPEDAGOGÍA', 'INTRODUCCIÓN A LA PSICOLOGÍA CLÍNICA', 'NEUROPSICOLOGÍA', 'PSICOLOGÍA DE LA PERSONALIDAD', 'PSICOLOGÍA DEL DESARROLLO II', 'RECLUTAMIENTO, SELECCIÓN E INDUCCIÓN DE PERSONAL', 'OPINIÓN PÚBLICA', 'PROYECTO DE FIN  DE CARRERA 4.1', 'GESTIÓN PR ...

# %%
#Crear vocabularios
totalvocab_lemmatized = []
totalvocab_tokenized = []
for i in lista_materias:
    doc = es_parsing(i)
    allwords_lemmatized = lemmatizing(doc,punt_stopwords)
    totalvocab_lemmatized.extend(allwords_lemmatized)
    
    allwords_tokenized = tokenizing(doc,punt_stopwords)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_dataframe = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_lemmatized)

# %%
print ('there are ' + str(vocab_dataframe.shape[0]) + ' items in vocab_frame')
# Out:
# there are 4435 items in vocab_frame

# %%
tokenize = lambda doc: doc.lower().split(" ")

# %%
tfidf_vectorizer = TfidfVectorizer(encoding='utf-8',max_df=0.9,
                                 min_df=0.1, stop_words=es_stopwords,
                                 use_idf=True, tokenizer=tokenize, analyzer='word', ngram_range=(1,3))

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(lista_materias)
# Out:
#   (15, 2)	1.0
#   (39, 2)	1.0
#   (40, 2)	1.0
#   (43, 2)	1.0
#   (65, 2)	1.0
#   (74, 2)	0.534427828994616
#   (74, 0)	0.4799394259540998
#   (74, 3)	0.4905709434337836
#   (74, 1)	0.49334084816629387
#   (86, 2)	0.534427828994616
#   (86, 0)	0.4799394259540998
#   (86, 3)	0.4905709434337836
#   (86, 1)	0.49334084816629387
#   (91, 0)	0.5678317706502028
#   (91, 3)	0.5804102609111068
#   (91, 1)	0.58368742428577
#   (94, 0)	0.5678317706502028
#   (94, 3)	0.5804102609111068
#   (94, 1)	0.58368742428577
#   (97, 0)	0.5678317706502028
#   (97, 3)	0.5804102609111068
#   (97, 1)	0.58368742428577
#   (102, 2)	0.534427828994616
#   (102, 0)	0.4799394259540998
#   (102, 3)	0.4905709434337836
#   :	:
#   (1247, 3)	0.4905709434337836
#   (1247, 1)	0.49334084816629387
#   (1248, 2)	0.534427828994616
#   (1248, 0)	0.4799394259540998
#   (1248, 3)	0.4905709434337836
#   (1248, 1)	0.49334084816629387
#   (1261, 0)	0.5678317706502028
#   (1261, 3)	0.5804102609111068
#   (1261, 1)	0.58368742428577
#   (1265, 0)	0.5678317706502028
#   (1265, 3)	0.5804102609111068
#   (1265, 1)	0.58368742428577
#   (1269, 0)	0.5678317706502028
#   (1269, 3)	0.5804102609111068
#   (1269, 1)	0.58368742428577
#   (1275, 0)	0.5678317706502028
#   (1275, 3)	0.5804102609111068
#   (1275, 1)	0.58368742428577
#   (1280, 0)	0.5678317706502028
#   (1280, 3)	0.5804102609111068
#   (1280, 1)	0.58368742428577
#   (1289, 0)	0.5678317706502028
#   (1289, 3)	0.5804102609111068
#   (1289, 1)	0.58368742428577
#   (1302, 0)	1.0

# %%
#Guardar Matriz TF-IDF con PICKLE
with open("tfidfmaterias.pkl", 'wb') as handle:
    pickle.dump(tfidf_matrix, handle)
#load the content
tfidf = pickle.load(open("tfidfmaterias.pkl", "rb" ) ) 
print (tfidf)

# %%
#Guardar Matriz TF-IDF con NPZ
sparse.save_npz("tfidf-materias.npz", tfidf_matrix)
tfidf_matrix1 = sparse.load_npz("tfidf-materias.npz")
#print (tfidf_matrix1)

# %%
terms = tfidf_vectorizer.get_feature_names()

# %%
#similaridad del coseno
dist = 1 - cosine_similarity(tfidf_matrix)
#print (dist)

for d in dist:
    print(d)
    #for a in d:
     #   print (a)

# %%
#cluster jerárquico
linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances
print (linkage_matrix)
# Out:
# [[0.00000000e+00 1.00000000e+00 0.00000000e+00 2.00000000e+00]
#  [2.00000000e+00 1.32800000e+03 0.00000000e+00 3.00000000e+00]
#  [3.00000000e+00 1.32900000e+03 0.00000000e+00 4.00000000e+00]
#  ...
#  [2.25000000e+03 2.65100000e+03 4.21263666e+01 1.92000000e+02]
#  [2.63200000e+03 2.64900000e+03 8.18409626e+01 1.13600000e+03]
#  [2.65200000e+03 2.65300000e+03 2.14636738e+02 1.32800000e+03]]

# %%
fig, ax = plt.subplots(figsize=(5,80)) # set size
ax = dendrogram(linkage_matrix, orientation="left", labels=lista_materias);

plt.tick_params(\
    axis= 'x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off',
    grid_linewidth=50)

plt.tight_layout() #show plot with tight layout

#uncomment below to save figure
plt.savefig('clusters_allmaterias.png', dpi=200) #save figure as ward_clusters
# Out:
# /Users/ela/Documents/entornos/jupyterenv/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.close()

# %%
close_connectionMySQL()
